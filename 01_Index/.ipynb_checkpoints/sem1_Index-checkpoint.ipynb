# %% [markdown]
# ## Семинар 1 Индекс

# %% [markdown]
# ## __Задача__:
#
# **Data:** Коллекция субтитров сезонов Друзей. Одна серия - один документ.
#
# **To do:** Постройте небольшой модуль поискового движка, который сможет осуществлять поиск по коллекции документов.
# На входе запрос и проиндексированная коллекция (в том виде, как посчитаете нужным), на выходе отсортированный по релевантности с запросом список документов коллекции.
#
# Релизуйте:
#     - функцию препроцессинга данных
#     - функцию индексирования данных
#     - функцию метрики релевантности
#     - собственно, функцию поиска
#
# [download_friends_corpus](https://yadi.sk/d/yVO1QV98CDibpw)

# %% [markdown]
# Напоминание про defaultdict:
# > В качестве multiple values словаря рекомендую использовать ``` collections.defaultdict ```
# > Так можно избежать конструкции ``` dict.setdefault(key, default=None) ```

# %% [markdown]
# С помощью обратного индекса посчитайте:
#
#
# a) какое слово является самым частотным
#
# b) какое самым редким
#
# c) какой набор слов есть во всех документах коллекции
#
# d) какой сезон был самым популярным у Чендлера? у Моники?
#
# e) кто из главных героев статистически самый популярный?

# %%
import os
import re
import numpy as np
import pandas as pd
from collections import Counter, defaultdict
from pymystem3 import Mystem
from sklearn.feature_extraction.text import CountVectorizer


mystem = Mystem()
cv = CountVectorizer()

# %%
def collecting_files():
    list_of_files = []
    curr_dir = 'friends'
    for root, dirs, files in os.walk(curr_dir):
        for d in dirs:
            for file in os.listdir('.' + os.sep + curr_dir + os.sep + d):
                if file.endswith('.txt'):
                    path = curr_dir + os.sep + d + os.sep + file
                    list_of_files.append(path)
    return list_of_files

# %%
latin = re.compile("[a-z]+")
num = re.compile("[0-9]+")
punct = re.compile("[«–»—!\$%&'()*+,./:;<=>?@^_`{|}~']*")
episode = re.compile("[0-9]x[0123456789-]+")
word = re.compile("[А-ЯЁа-яё]+(?:(?:-[А-ЯЁа-яё]+)*)?")
other = set(["", "\n", "-", " "])

# %%
def preproc(text):
    text = text.lower().replace("\n", " ")
    text = latin.sub("", text)
    text = num.sub("", text)
    text = punct.sub("", text)
    return text

# %%
texts_done = []
episodes = []


list_of_files = collecting_files()
for path in list_of_files:
    with open(path, "r", encoding="utf-8") as f:
        text = f.read()
    
    words = re.findall(word, preproc(text))
    
    lemmas = []
    for w in words:
        lemma = mystem.lemmatize(w)
        lemmas += [l for l in lemma[:-1] if l not in other]
    lemmas_done.append(lemmas)
    text_lem = " ".join(lemmas)
    texts_done.append(text_lem)
   
    ep = re.search(episode, path).group(0)
    episodes.append(ep)

# %%
term_doc_matrix = pd.DataFrame(cv.fit_transform(texts_done).A, columns=cv.get_feature_names(), index=None)
term_doc_matrix["episode"] = episodes
term_doc_matrix = term_doc_matrix.set_index(term_doc_matrix["episode"])
del term_doc_matrix["episode"]
term_doc_matrix.head()
# Out:
#          аа  ааа  ааааа  ааааааа  аааааау  ааааах  аарон  аббатство  \
# episode
# 2x08      0    0      0        0        0       0      0          0
# 2x20      0    0      0        0        0       0      0          0
# 2x24      0    0      0        0        0       0      0          0
# 2x16      0    0      0        0        0       0      0          0
# 2x07      0    0      0        0        0       0      0          0
#
#          абонемент  абрикос   ...    ярмарка  ярость  ясмин  ясно  ясность  \
# episode                       ...
# 2x08             0        0   ...          0       0      0     0        0
# 2x20             0        0   ...          0       0      0     0        0
# 2x24             0        0   ...          0       0      0     1        0
# 2x16             0        0   ...          0       0      0     0        0
# 2x07             0        0   ...          0       0      0     1        0
#
#          ясный  яхта  ящерица  ящик  ящичек
# episode
# 2x08         0     0        0     0       0
# 2x20         0     0        0     0       0
# 2x24         0     0        0     0       0
# 2x16         0     0        0     0       0
# 2x07         0     0        0     0       0
#
# [5 rows x 14045 columns]

# %%
def inverted_index(texts_done, episodes) -> dict:
    inv_index = defaultdict(dict)
    for i, text in enumerate(texts_done):
        ep = episodes[i]
        count = Counter(mystem.lemmatize(text))
        for data in count.most_common():
            lemma, res = data
            if lemma not in other:
                inv_index[lemma][ep] = res
    return inv_index

# %%
inv_index = inverted_index(texts_done, episodes)

# %% [markdown]
# a) какое слово является самым частотным

# %%
max_freq = 0
word = ""
for lemma in inv_index:
    freq = sum(inv_index[lemma].values())
    if freq > max_freq:
        max_freq = freq
        word = lemma
print(word, max_freq)
# Out:
# я 18212

# %% [markdown]
# b) какое самым редким

# %%
words = []
for lemma in inv_index:
    if sum(inv_index[lemma].values()) == 1:
        words.append(lemma)
print(words)
# Out:
# ['программный', 'модем', 'килобит', 'половый', 'заострять', 'некий', 'луль', 'гарный', 'муй', 'импресибо', 'впечатляющий', 'исп', 'растаттер', 'синтетический', 'сертификат', 'абы', 'доминировать', 'пасха', 'усякий', 'пузыриться', 'ненно', 'послевкусие', 'отчего', 'заживать', 'влазить', 'брюлик', 'амур', 'детруа', 'систематически', 'столбец', 'село', 'неасфальтировать', 'дума', 'толстоватый', 'стружка', 'вселенский', 'вскричать', 'впадать', 'гениально', 'долбогрыз', 'карма', 'навозный', 'смело', 'моколатно', 'столовый', 'лабораторный', 'хитросплетение', 'шип', 'эверь', 'арыбахис', 'перерабатывать', 'занюханый', 'тренажерка', 'прауер', 'проблемный', 'ден', 'спайк', 'дырявить', 'свеженький', 'стойкий', 'поползти', 'заготавливать', 'убиственный', 'обеденный', 'порулить', 'кузнечка', 'лопатка', 'са', 'соперничать', 'поняньчить', 'нассау', 'кофей', 'сеть', 'взбадриваться', 'прекрасность', 'янки', 'янковская', 'костыль', 'разгребать', 'вассар', 'столетие', 'космо', 'распланировать', 'рид', 'ухудшаться', 'обводить', 'флоренс', 'хендерсон', 'првет', 'берта', 'дьявольски', 'тереза', 'жестковатый', 'запивать', 'беседовать', 'ершистый', 'мечтатель', 'сладобуська', 'дабы', 'манеж', 'захват', 'киберш', 'веб', 'гугенхайм', 'чендлеров', 'осуждение', 'сосредотачивать', 'копакабан', 'промелькнуть', 'хантер', 'тир', 'обуваться', 'стоянка', 'прядь', 'гавана', 'тренировать', 'чайник', 'закипать', 'адский', 'хрустика', 'хипповый', 'клякса', 'намерение', 'краденое', 'верхом', 'берка', 'берк', 'скупаться', 'обвисать', 'трехствольный', 'пулемет', 'породистый', 'полублондинка', 'суффраж', 'кокон', 'джонни', 'шапиро', 'моделька', 'жалюзи', 'кристалл', 'нализывать', 'одноразовый', 'зализываться', 'экологичный', 'вздрючивать', 'трусца', 'касание', 'нагораживать', 'объедать', 'перекидывать', 'полнеть', 'теплоизоляция', 'валяние', 'обтяжка', 'двас', 'поматросить', 'флафить', 'флафи', 'мяувингтон', 'твердо', 'забеспокоиться', 'воскресный', 'электрогитара', 'лго', 'толстячок', 'жизнерадостный', 'прикорнуть', 'амое', 'застолбить', 'продюсерша', 'незаезженный', 'демо', 'сушиться', 'фен', 'утеночек', 'вычищать', 'таймер', 'лейтенант', 'жемчужина', 'подпевка', 'пребывание', 'черепной', 'гребень', 'флинстоун', 'мудила', 'лосиный', 'кепка', 'этнический', 'чорицо', 'лоснить', 'протягиваться', 'существенный', 'мять', 'уживаться', 'джониновыеяйца', 'балаган', 'геллерский', 'потота', 'подпись', 'почитай', 'жительство', 'ку-ку', 'чизбургер', 'многофункциональный', 'ремонтировать', 'копировщик', 'нарния', 'зрелость', 'электричка', 'гарден', 'земляной', 'разворот', 'кападосец', 'роджерс', 'страшновато', 'матадор', 'перебарывать', 'порник', 'врубать', 'двухсосковый', 'знет', 'провокационный', 'деградационный', 'печать', 'копировалку', 'копировалок', 'бумагоприемник', 'адно', 'награждение', 'дебра', 'гоба', 'оратор', 'издалека', 'напрыгивать', 'униженный', 'дейсвительно', 'спонтанность', 'повлечь', 'акр', 'пожервовать', 'кверху', 'дайк', 'экранчик', 'подыгрывать', 'опытный', 'восемьдесят', 'плот', 'притапливать', 'покачивать', 'сд', 'чейнджер', 'поссать', 'минералка', 'шериф', 'кадиллак', 'катаракт', 'кебабной', 'надобность', 'услеживать', 'ствой', 'романтика', 'покраска', 'хохолок', 'чайка', 'луч', 'прятно', 'ленивец', 'измерение', 'ксанада', 'всовывать', 'напи', 'генри', 'сорентино', 'гранатовый', 'скопление', 'медведица', 'неверо', 'нагреваться', 'проболтаться', 'помчаться', 'бро', 'жа', 'ло', 'вать', 'шу', 'стра', 'гарднер', 'нагадить', 'поддых', 'удавка', 'догадливый', 'передразнивать', 'помимо', 'всемогущество', 'подражание', 'фигурный', 'зна', 'порисовать', 'перегревать', 'утюг', 'подравнивать', 'расшифровывать', 'поучать', 'ктой', 'дадли', 'раскошный', 'ширина', 'манжет', 'завиваться', 'накручивать', 'бигуди', 'всего-то', 'советчик', 'напутывать', 'родди', 'франкс', 'ротисер', 'неуловимый', 'макдоналдс', 'макдоналд', 'соусный', 'лаверный', 'кудри', 'смыслить', 'биржевой', 'бык', 'единоутробный', 'ветчинный', 'жирно', 'кусючий', 'сьест', 'сьем', 'сенчури', 'соваться' ...

# %% [markdown]
# c) какой набор слов есть во всех документах коллекции

# %%
words = []
for lemma in inv_index:
    if len(inv_index[lemma]) == len(set(episodes)):
        words.append(lemma)
print(words)
# Out:
# ['я', 'не', 'ты', 'и', 'что', 'это', 'а', 'как', 'на', 'быть', 'он', 'в', 'она', 'нет', 'с', 'так', 'хорошо', 'мы', 'все', 'у', 'ну', 'давать', 'мой', 'но', 'весь', 'просто', 'то', 'еще', 'о', 'да', 'такой', 'ладно', 'знать', 'же', 'мочь', 'хотеть', 'они', 'этот', 'если', 'думать']

# %% [markdown]
# d) какой сезон был самым популярным у Чендлера?

# %%
def task_d(char):
    seasons = {str(num): 0 for num in range(1,8)}
    char = char.lower()
    char = mystem.lemmatize(char)[0]
    for ep in inv_index[char]:
        seasons[ep[0]] += inv_index[char][ep]
#    print(seasons)
    return max(seasons, key=seasons.get)

# %%
task_d("Чендлер")
# Out:
# '6'

# %% [markdown]
# у Моники?

# %%
task_d("Моника")
# Out:
# '7'

# %% [markdown]
# e) кто из главных героев статистически самый популярный?

# %%
max_freq = 0
character = ""
for char in ["Чендлер", "Моника", "Росс", "Фиби", "Джоуи", "Рейчел"]:
    char = char.lower()
    char = mystem.lemmatize(char)[0]
    freq = sum(inv_index[char].values())
    if freq > max_freq:
        max_freq = freq
        character = char
print(character.capitalize())
# Out:
# Росс
